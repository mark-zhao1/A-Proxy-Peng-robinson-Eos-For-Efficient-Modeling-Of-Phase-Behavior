# %% [markdown]
# # Train for Monahans Clearfork

# %% [markdown]
# Training sequence:

# %% [markdown]
# Start on 16 February 2021
#
# Settings were
#
#     T = 549.67 # R, 90
#     P_min = 1000 # [psia]
#     P_max = 2000
#     num_P = 1000
#
#     T_min = T
#     T_max = T
#     num_T = 1
#
#     num_x = 10000
#
# Added data along mixing line at P = 1200 psia, from 0 to 1 mixr.
# 100,000 extra data per component. This should improve the accuracy for those points. If it does not, investigate the data itself.

# %% [markdown]
# Data on mixing line generated by Data_generation/Along_mixing_line_gen/mixing_line_gen.py.
#
# Changed
#
#     tf.keras.callbacks.ModelCheckpoint(
#         monitor='val_mae')
#
# This should only save the lowest validation mae.
# The validation set can be chosen to be the mixing line data points. Change splitting
